# %% [markdown]
# ## 阿司匹林 (Asprin)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True
m1 = Chem.MolFromSmiles("C1=CC(OC(C)=O)=C(C(O)=O)C=C1")
m1

# %% [markdown]
# ## 布洛芬 (Ibuprofen)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True
m2 = Chem.MolFromSmiles("C1=CC([C@@H](C)C(O)=O)=CC=C1CC(C)C")
m2

# %% [markdown]
# ## 对乙酰氨基酚/扑热息痛 (Paracetamol/Acetaminophen)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True
m3 = Chem.MolFromSmiles("CC(=O)Nc1ccc(O)cc1")
m3

# %% [markdown]
# ## 阿莫西林 (Amoxicillin)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True
m4 = Chem.MolFromSmiles("OC1=CC=C([C@@H](N)C(=O)N[C@H]2[C@H]3SC(C)(C)[C@@H](C(=O)O)N3C2=O)C=C1")
m4

# %% [markdown]
# ## 奥美拉唑 (Omeprazole)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True
m5 = Chem.MolFromSmiles("CC1=CN=C(C(=C1OC)C)CS(=O)C2=NC3=C(N2)C=C(C=C3)OC")
m5

# %% [markdown]
# ## 二甲双胍 (Metformin)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True
m6 = Chem.MolFromSmiles("CN(C(=N)N=C(N)N)C")
m6

# %% [markdown]
# ## 阿托伐他汀 (Atorvastatin)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True
m7 = Chem.MolFromSmiles("CC(C)C1=C(C(=C(N1CC[C@H](C[C@H](CC(=O)O)O)O)C2=CC=C(C=C2)F)C3=CC=CC=C3)C(=O)NC4=CC=CC=C4")
m7

# %% [markdown]
# ## 氯雷他定 (Loratadine)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True
m8 = Chem.MolFromSmiles("CCOC(=O)N1CCC(CC1)=C1C2=C(CCC3=C1N=CC=C3)C=C(Cl)C=C2")
m8

# %% [markdown]
# ## 硝酸甘油 (Nitroglycerin)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True
m9 = Chem.MolFromSmiles("O=N(=O)OC(CON(=O)=O)CON(=O)=O")
m9

# %% [markdown]
# ## 甲硝唑 (Metronidazole)

# %%
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
IPythonConsole.ipython_useSVG = True
m10 = Chem.MolFromSmiles("CC1=NC=C(N1CCO)[N+](=O)[O-]")
m10
